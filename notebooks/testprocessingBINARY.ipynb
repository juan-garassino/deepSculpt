# %%
from deepSculpt.manager.tools.params import COLORS
from deepSculpt.sculptor.sculptor import Sculptor
from deepSculpt.manager.tools.plotter import Plotter
from deepSculpt.curator.tools.preprocessing import BinaryEncoderDecoder

import os

# %%
from deepSculpt.collector.collector import Collector

collector = Collector(
    void_dim=int(os.environ.get("VOID_DIM")),
    edge_elements=(0, 0.3, 0.5),
    plane_elements=(0, 0.3, 0.5),
    volume_elements=(2, 0.3, 0.5),
    step=None,
    directory='.',
    chunk_size=50,
    n_chunks=1,
    grid=1,
)

# Creates the data
volumes_void, materials_void = collector.create_collection()
# Out:
#  ✅ Just created 'volume_data' chunk 1 shaped (50, 16, 16, 16) and 'material_data' shaped(50, 16, 16, 16)
#
#  🔽 Just saved 'volume_data' & 'material_data' chunk 1 @ .
#
#  ✅ Creating a color plots
#
#  🔽 Plotting [02-03-2023-17-27-40]
#
#  ✅ Just saved a snapshot image[02-03-2023-17-27-40].png @ /Users/juan-garassino/code/juan-garassino/deepSculpt/data/samples/picture
#
#  🆗 Just ploted 'volume_data[34]' and 'material_data[34]'
#
#  ✅ Creating a color plots
#
#  🔽 Plotting [02-03-2023-17-27-46]
#
#  ✅ Just saved a snapshot image[02-03-2023-17-27-46].png @ /Users/juan-garassino/code/juan-garassino/deepSculpt/data/samples/picture
#
#  🆗 Just ploted 'volume_data[11]' and 'material_data[11]'

# %%
preprocessing_class_b = BinaryEncoderDecoder(materials_void,)
                                             #materials=materials_void,
                                             #verbose=1)

b_encode, b_classes = preprocessing_class_b.binary_encode()
# Out:
#  🔀 A number of 50 samples shaped (50, 16, 16, 16) have been encoded to (50, 16, 16, 16, 3) in 5 classes: ['crimson' 'dimgrey' 'gold' 'turquoise' None]

# %%
decode_volumes_void, decode_materials_void = preprocessing_class_b.binary_decode(b_encode)
# Out:
#  🔀 A number of 50 samples shaped (50, 16, 16, 16, 3) have been decoded to (50, 16, 16, 16) in 5 classes: ['crimson' 'dimgrey' 'gold' 'turquoise' None]
